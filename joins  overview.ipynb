-- %% [markdown]
-- ### 1. Streaming Table to static Table

-- %% [markdown]
-- ![](/Volumes/workspace/monschema1/images/STream_to_static.JPG)

-- %% [markdown]
-- ### 2. Streaming to STreaming with Materialized view

-- %% [markdown]
-- ![](/Volumes/workspace/monschema1/images/Streaming_to_stream_with_MV.JPG)

-- %% [markdown]
-- ### 3. STreaming to STreaming (join)

-- %% [markdown]
-- ![](/Volumes/workspace/monschema1/images/Stream_to_Stream_join.JPG)

-- %% [markdown]
-- ### Pipelines modes
--
-- There are 2 modes when deploying a pipeline:
-- - Development mode
-- - Production mode

-- %% [markdown]
-- ![](/Volumes/workspace/monschema1/images/Developppement_mode.JPG)

-- %% [markdown]
-- ![](/Volumes/workspace/monschema1/images/production_mode.JPG)

-- %% [markdown]
-- ![](/Volumes/workspace/monschema1/images/Production_pipline.JPG)
