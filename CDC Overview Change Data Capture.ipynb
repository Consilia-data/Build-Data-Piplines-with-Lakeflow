-- %% [markdown]
-- ![](/Volumes/workspace/monschema1/images/CDC_def.JPG)

-- %% [markdown]
-- ![](/Volumes/workspace/monschema1/images/SCD1.JPG)

-- %% [markdown]
-- ![](/Volumes/workspace/monschema1/images/SCD2.JPG)

-- %% [markdown]
-- ![](/Volumes/workspace/monschema1/images/Change data capture overview.JPG)

-- %% [markdown]
-- ![](/Volumes/workspace/monschema1/images/add_features2.JPG)

-- %% [markdown]
-- ![](/Volumes/workspace/monschema1/images/add_features1.JPG)
